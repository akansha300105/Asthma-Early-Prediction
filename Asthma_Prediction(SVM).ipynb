# %%
# Importing the dependencies
import pandas as pd
import numpy as np

# %%
asthma_data = pd.read_csv('asthma_disease_data.csv')
asthma_data.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       5034   63       0          1               0  15.848744        0
# 1       5035   26       1          2               2  22.757042        0
# 2       5036   57       0          2               1  18.395396        0
# 3       5037   40       1          2               1  38.515278        0
# 4       5038   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  ...  LungFunctionFEV1  \
# 0          0.894448     5.488696      8.701003  ...          1.369051
# 1          5.897329     6.341014      5.153966  ...          2.197767
# 2          6.739367     9.196237      6.840647  ...          1.698011
# 3          1.404503     5.826532      4.253036  ...          3.032037
# 4          4.604493     3.127048      9.625799  ...          3.470589
#
#    LungFunctionFVC  Wheezing  ShortnessOfBreath  ChestTightness  Coughing  \
# ...

# %%
asthma_data.shape
# Out:
# (2392, 29)

# %%
asthma_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PatientID               2392 non-null   int64
#  1   Age                     2392 non-null   int64
#  2   Gender                  2392 non-null   int64
#  3   Ethnicity               2392 non-null   int64
#  4   EducationLevel          2392 non-null   int64
#  5   BMI                     2392 non-null   float64
#  6   Smoking                 2392 non-null   int64
#  7   PhysicalActivity        2392 non-null   float64
#  8   DietQuality             2392 non-null   float64
#  9   SleepQuality            2392 non-null   float64
#  10  PollutionExposure       2392 non-null   float64
#  11  PollenExposure          2392 non-null   float64
#  12  DustExposure            2392 non-null   float64
#  13  PetAllergy              2392 non-null   int64
# ...

# %%
# finding missing values
asthma_data.isnull().sum()
# Out:
# PatientID                 0
# Age                       0
# Gender                    0
# Ethnicity                 0
# EducationLevel            0
# BMI                       0
# Smoking                   0
# PhysicalActivity          0
# DietQuality               0
# SleepQuality              0
# PollutionExposure         0
# PollenExposure            0
# DustExposure              0
# PetAllergy                0
# FamilyHistoryAsthma       0
# HistoryOfAllergies        0
# Eczema                    0
# HayFever                  0
# GastroesophagealReflux    0
# LungFunctionFEV1          0
# LungFunctionFVC           0
# Wheezing                  0
# ShortnessOfBreath         0
# ChestTightness            0
# Coughing                  0
# NighttimeSymptoms         0
# ExerciseInduced           0
# Diagnosis                 0
# DoctorInCharge            0
# dtype: int64

# %%
# counting the variables based on the label
asthma_data['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 0    2268
# 1     124
# Name: count, dtype: int64

# %% [markdown]
# 0 --> No asthma
#
# 1 --> Asthma predicted

# %%
asthma_data.drop(columns='DoctorInCharge', axis=1, inplace=True)

# %%
asthma_data.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       5034   63       0          1               0  15.848744        0
# 1       5035   26       1          2               2  22.757042        0
# 2       5036   57       0          2               1  18.395396        0
# 3       5037   40       1          2               1  38.515278        0
# 4       5038   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  ...  GastroesophagealReflux  \
# 0          0.894448     5.488696      8.701003  ...                       0
# 1          5.897329     6.341014      5.153966  ...                       0
# 2          6.739367     9.196237      6.840647  ...                       0
# 3          1.404503     5.826532      4.253036  ...                       0
# 4          4.604493     3.127048      9.625799  ...                       0
#
#    LungFunctionFEV1  LungFunctionFVC  Wheezing  ShortnessOfBreath  \
# ...

# %%
asthma_data.tail()
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 2387       7421   43       1          0               2  29.059613        0
# 2388       7422   18       1          0               1  20.740850        0
# 2389       7423   54       0          3               2  37.079560        0
# 2390       7424   46       1          0               2  23.444712        0
# 2391       7425   26       1          0               0  28.123021        1
#
#       PhysicalActivity  DietQuality  SleepQuality  ...  \
# 2387          3.019854     6.119637      8.300960  ...
# 2388          5.805180     4.386992      7.731192  ...
# 2389          4.735169     8.214064      7.483521  ...
# 2390          9.672637     7.362861      6.717272  ...
# 2391          1.613138     7.412878      8.512253  ...
#
#       GastroesophagealReflux  LungFunctionFEV1  LungFunctionFVC  Wheezing  \
# 2387                       0          3.125249         5.166032         0
# ...

# %%
asthma_data_zero=asthma_data[asthma_data['Diagnosis']==0]
asthma_data_one=asthma_data[asthma_data['Diagnosis']==1]
asthma_data_zero=asthma_data_zero.sample(n=124)
asthma_data=pd.concat([asthma_data_zero,asthma_data_one])
asthma_data.shape
# Out:
# (248, 28)

# %%
# separating all the data and the labels
X = asthma_data.drop(columns='Diagnosis', axis=1)
Y = asthma_data['Diagnosis']

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (248, 27) (198, 27) (50, 27)

# %% [markdown]
# Data Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Training the model

# %%
from sklearn import svm
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train_scaled, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model evaluation and accuracy score

# %%
# accuracy score on training data
from sklearn.metrics import accuracy_score
X_train_prediction = classifier.predict(X_train_scaled)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.9696969696969697

# %%
# Accuracy score on test data
Y_train_prediction = classifier.predict(X_test_scaled)
test_data_accuracy = accuracy_score(Y_test, Y_train_prediction)

# %%
print('Accuracy score of the testing data :', test_data_accuracy)
# Out:
# Accuracy score of the testing data : 0.94

# %%
# classification report
from sklearn.metrics import classification_report
y_pred=classifier.predict(X_test_scaled)
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        25
#            1       0.89      1.00      0.94        25
#
#     accuracy                           0.94        50
#    macro avg       0.95      0.94      0.94        50
# weighted avg       0.95      0.94      0.94        50

# %% [markdown]
# Making a predictive system

# %%
input_data = (7412,57,0,0,1,25.13562490468526,0,6.156111777267046,0.7307083675515025,6.9143963548941345,0.8177821095324367,8.26901287803609,9.005851340893757,0,1,1,0,0,0,2.336062612885746,2.555341948417303,0,0,0,0,0,1)
# changing the input data into array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
    print('The person does not have asthma disease')
else:
    print('The person has asthma disease')
# Out:
# [1]
# The person has asthma disease
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
